# %%
data = (1,2,"sanjit",[5,6,7],(6,9),6.7)
print(tuple(data))
# Out:
# (1, 2, 'sanjit', [5, 6, 7], (6, 9), 6.7)

# %%
data1 = (1,2,3,4,5)
type(data1)
# Out:
# tuple

# %%
len(data1)
# Out:
# 5

# %%
sum(data1)
# Out:
# 15

# %%
max(data1)
# Out:
# 5

# %%
min(data1)
# Out:
# 1

# %%
data6 = (1,2,3,4,5)
any("2,3,4")
# Out:
# True

# %%
sorted(data1)
# Out:
# [1, 2, 3, 4, 5]

# %%
tuple(sorted(data1))
# Out:
# (1, 2, 3, 4, 5)

# %%
lst1 = (3,1,2,4,6)
sorted(lst1)
# Out:
# [1, 2, 3, 4, 6]

# %%
data = (1,2,3)
a,b,c = data

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
data1 = (3,4,5)
l,b,_ = data1
print(l)
print(b)
# Out:
# 3
# 4

# %%
t = (10,20,30)
print(t[1])
# Out:
# 20

# %%
t = (10,20,30,40)
print(t[1:3])
# Out:
# (20, 30)

# %%
t1 = (10, 20)
t2 = (30 , 40)
print(t1+t2)
# Out:
# (10, 20, 30, 40)

# %%
t = (1,2)
print(t*3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
t = (10,20,30)
print(20 in t)
# Out:
# True

# %%
t1 = (1,2)
t2 = (1,3)
print(t1<t2)
# Out:
# True

# %%
lst1 = [1,2,3]
lst1.pop()
print(lst1)
# Out:
# [1, 2]

# %%
data2 = [1,2,3,4]
del data2[1]
data2
# Out:
# [1, 3, 4]

# %%
# tuple is immutable
data2 = (1,2,3,4)
del data2[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2379/2816071307.py in <cell line: 0>()
#       1 data2 = (1,2,3,4)
# ----> 2 del data2[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
s = {20,"jessica",35.75}
print(type(s))
# Out:
# <class 'set'>

# %%
set((20,"jessa",22.5))
# Out:
# {20, 22.5, 'jessa'}

# %%
dat = {}
print(type(dat))
# Out:
# <class 'dict'>

# %%
setA = {1,2,3,4,5,6}
setB = {5,6,7,8,9}
print(setA-setB) #difference operation in set (symbol -)
# Out:
# {1, 2, 3, 4}

# %%
setA = {1,2,3,4,5,6}
setB = {5,6,7,8,9}
print(setA|setB) #union operation in set (symbol |)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
setA = {1,2,3,4,5,6}
setB = {5,6,7,8,9}
print(setA&setB)  #intersection operation in set (symbol &)
# Out:
# {5, 6}

# %%
setA = {1,2,3,4,5,6}
setB = {5,6,7,8,9}
print(setA^setB) #symmetric difference operation in set (symbol ^)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
setA = {1,2,3,4,5,6}
setB = {5,6,7,8,9}
print(5 in setB) #membership operation in set (in)
# Out:
# True

# %%
setA = {1,2,3,4,5,6}
setB = {5,6,7,8,9}
print(setA<=setB) #subset operation in set (<=)
# Out:
# False

# %%
setA = {1,2}
setB = {1,2,3,4}
print(setA<=setB) #superset operation in set (>=
# Out:
# True
