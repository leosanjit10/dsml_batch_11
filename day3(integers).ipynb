# %%
number = 122
print(type(number))
# Out:
# <class 'int'>

# %%
num = 3.4
type(num)
# Out:
# float

# %%
com = 3 + 3j
type(com)
# Out:
# complex

# %%
a = 3.45
b = int(a)
b
# Out:
# 3

# %%
a = 40
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**2)
print(a%6)
print(a//9)
# Out:
# 60
# 20
# 800
# 2.0
# 1600
# 4
# 4

# %%
print(a==b)
print(a<b)
print(a>b)
print(a<=b)
print(a>=b)
print(a!=b)
# Out:
# False
# False
# True
# False
# True
# True

# %%
import math
print(math.ceil(44.9))
print(math.floor(44.9))
print(math.gcd(3,6,9,12))
print(round(22.542,2))
user = 640
capacity = 128
result = min(user,capacity)
print(result)
# Out:
# 45
# 44
# 3
# 22.54
# 128

# %%
ab = 'hello'
bc = "hello"
print(ab==bc)
# Out:
# True

# %%
text1 = "It's a sunny day"
text2 = 'He said "Hello"'
print(text1)
print(text2)
# Out:
# It's a sunny day
# He said "Hello"

# %%
print(text1+ " " + text2)
# Out:
# It's a sunny day He said "Hello"

# %%
print(text1*3)
# Out:
# It's a sunny dayIt's a sunny dayIt's a sunny day

# %%
data = "python"
print(data[5])
print(data[-1])
# Out:
# n
# n

# %%
data[1:4]
# Out:
# 'yth'

# %% [markdown]
# data[start:end:step] for slicing

# %%
data[5:1:-1]
# Out:
# 'noht'

# %%
data[2:5:2]
# Out:
# 'to'

# %%
data[ :4]
# Out:
# 'pyth'

# %%
data2 = "Hello Python"
data2[1:11:3]
# Out:
# 'eoyo'

# %%
len(data2)
# Out:
# 12

# %%
data3 = "i am a boy"
print(data3.replace("boy","girl"))
# Out:
# i am a girl

# %%
data4 = "   It's a good day   "

data4.lower()
# Out:
# "   it's a good day   "

# %%
data4.upper()
# Out:
# "   IT'S A GOOD DAY   "

# %%
data4.title()
# Out:
# "   It'S A Good Day   "

# %%
data4.strip()
# Out:
# "It's a good day"

# %%
data4.replace("good","bad")
# Out:
# "   It's a bad day   "

# %%
data4.split()
# Out:
# ["It's", 'a', 'good', 'day']

# %%
data6 = "lion", "is", "the", "king", "of", "the", "jungle"
result = " ".join(data6)
print(result)
# Out:
# lion is the king of the jungle

# %%
data5 = "image.png"

# %%
data5.endswith("png")
# Out:
# True

# %%
data5.startswith("image")
# Out:
# True
