# %%
data = {
    "id": 101,
    "name": "jane doe",
    "is active": True,
    "roles": ["admin","editor"],
    "contact": {
    "email": "jane@example.com",
    "phone": None
    }}

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
dict({"name": "sanjit", "roll no": 20})
# Out:
# {'name': 'sanjit', 'roll no': 20}

# %%
dict({"student1":{"name":"sanjit","age":22},"student2":{"name":"Ram","age":21}})
# Out:
# {'student1': {'name': 'sanjit', 'age': 22},
#  'student2': {'name': 'Ram', 'age': 21}}

# %%
students = dict({
    'student1':dict({'name':'sanjit','age':20}),
    'student2':dict({'name':'Ram','age':21})
})
students
# Out:
# {'student1': {'name': 'sanjit', 'age': 20},
#  'student2': {'name': 'Ram', 'age': 21}}

# %%
person = dict([('name','rita'),('country','Nepal'),('telephone',9818000000)])
print(person)
# Out:
# {'name': 'rita', 'country': 'Nepal', 'telephone': 9818000000}

# %%
data_new = {
    'name': 'sanjit',
    'age': 21
}

# %%
data_new
# Out:
# {'name': 'sanjit', 'age': 21}

# %%
data_new['age']
# Out:
# 21

# %%
data_new['name']
# Out:
# 'sanjit'

# %%
data_new.get('name')
# Out:
# 'sanjit'

# %%
data_new['name'] = 'Ram'
data_new
# Out:
# {'name': 'Ram', 'age': 21}

# %%
data_new.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
data_new.values()
# Out:
# dict_values(['Ram', 21])

# %%
data_new.items()
# Out:
# dict_items([('name', 'Ram'), ('age', 21)])

# %%
data_new.pop('name')
# Out:
# 'Ram'

# %%
data_new
# Out:
# {'age': 21}

# %%
data_new.popitem()
# Out:
# ('age', 21)

# %%
data_new = {
    'name': 'sanjit',
    'age': 21
}

# %%
del data_new['age']

# %%
data_new
# Out:
# {'name': 'sanjit'}

# %%
del data_new

# %%
data_new = {
    'name': 'sanjit',
    'age': 21
}

# %%
data_new.clear()

# %%
data_new
# Out:
# {}

# %%
data5 = {'name':'sanjit',
         'age':23}

# %%
data5.pop('age')
# Out:
# 23

# %%
data5.pop('age','age not found')
# Out:
# 'age not found'

# %%
data6 = {
    'name': 'sanjit',
    'age': 21
}

# %%
del data6['age']

# %%
del data6['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3683/3362045734.py in <cell line: 0>()
# ----> 1 del data6['age']
#
# KeyError: 'age'

# %%
dict1 = {'name' :'sanjit'}
dict2 = {'roll number': 26}
dict1.update(dict2)
dict1
# Out:
# {'name': 'sanjit', 'roll number': 26}

# %%
dict1 = {'name' :'sanjit'}
dict2 = {'name': 'nirajan'}
dict1.update(dict2)
dict1
# Out:
# {'name': 'nirajan'}

# %%
dict1 = {'name' :'sanjit'}
dict2 = {'roll number': 26}
dict3 = {'age': 30}
dict4 = {**dict1, **dict2, **dict3}
dict4
# Out:
# {'name': 'sanjit', 'roll number': 26, 'age': 30}

# %%
dict1 = {'name' :'sanjit'}
dict2 = {'age': '30'}
dict1 | dict2
# Out:
# {'name': 'sanjit', 'age': '30'}

# %%
student = {'b':2, 'a':1, 'c':3}
result = sorted(student)
print(result)
# Out:
# ['a', 'b', 'c']

# %%
student = {'name':'sanjit','age':30,'faculty':'dsml'}
student['phone'] = 9854678986
student['age'] = 29
student['city'] = 'ktm'
del student['city']
student
# Out:
# {'name': 'sanjit', 'age': 29, 'faculty': 'dsml', 'phone': 9854678986}

# %%
if 'email' in student:
   print('email key exists')
else:

   print('email key does not exist')
# Out:
# email key does not exist
