# %%
#from day 10 built in function
lst = [1,2,3,4,5,6,7,8,9]
def even(n):
  if n %2==0:
    return n

# %%
lst = [1,2,3,4,5,6,7,8,9]
res = filter(even,lst)
print(list(res))
# Out:
# [2, 4, 6, 8]

# %%
1*2 = 2
2*3 = 6
6*4 = 24
24*5 = 120
# Out:
#   File "/tmp/ipykernel_2944/1386761840.py", line 1
#     1*2 = 2
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
#1*2 = 2
2*3 = 6
6*4 = 24
24*5 = 120
from functools import reduce

def mux(a,b):
  return (a*b)
lst = [1,2,3,4,5]
resdata = reduce(mux,lst)
resdata
# Out:
# 120

# %%
lst = [2,9,7,5,1]
from functools import reduce
def maximum(x,y):
  if x>y:
    return x
  return y
print(reduce(maximum,lst))
# max(4,9) -> 9
# max(9,2)-> 9
# max(9,8) -> 9
#max(9,1)-. 9
# Out:
# 9

# %%
#day 11 from here
def sum(a,b):
  '''adding two numbers
  '''
  return a+b

# %%
print(sum.__doc__)
# Out:
# adding two numbers

# %%
help(sum)
# Out:
# Help on function sum in module __main__:
#
# sum(a, b)
#     adding two numbers

# %%
def calculate_area(length, width):
  '''
  calculate the area of a rectangle

          parameters:
  length(float):length of the rectangle
  width (float): width of the rectangle
           returns:
  float: area of the rectangle
  '''
  return length*width

# %%
print(calculate_area.__doc__)
# Out:
#   calculate the area of a rectangle
#
#           parameters:
#   length(float):length of the rectangle
#   width (float): width of the rectangle
#            returns:
#   float: area of the rectangle

# %%
help(calculate_area)
# Out:
# Help on function calculate_area in module __main__:
#
# calculate_area(length, width)
#     calculate the area of a rectangle
#
#             parameters:
#     length(float):length of the rectangle
#     width (float): width of the rectangle
#              returns:
#     float: area of the rectangle

# %%
num = [1,2,3,45,]
print(*num)
# Out:
# 1 2 3 45

# %%
def data(*args):
  return args
print(data("welcome","to","skillshikya"))
# Out:
# ('welcome', 'to', 'skillshikya')

# %%
def data(**kwargs):
  return kwargs
print(data(name = 'sanjit',age = 30))
# Out:
# {'name': 'sanjit', 'age': 30}

# %%
def data3(n, *args, **kwargs):
  print(n)
  print(args)
  print(kwargs)
data3(3,2,3,4,5,s=1,s1=4)
# Out:
# 3
# (2, 3, 4, 5)
# {'s': 1, 's1': 4}

# %%
def pizza(n,*ingridents,**customer_details):
  print("the number of pizza is: ",n)
  print("ingridents: ")
  for i in ingridents:
    print("-",i)
  print("customer details: ")
  for i in customer_details.items():
    print(i)
pizza(1,"olive oil","tomato", "chicken",name = "sanjit",address = "ktm")
# Out:
# the number of pizza is:  1
# ingridents:
# - olive oil
# - tomato
# - chicken
# customer details:
# ('name', 'sanjit')
# ('address', 'ktm')
